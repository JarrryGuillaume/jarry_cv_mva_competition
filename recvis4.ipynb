# %%
# !git clone https://github.com/JarrryGuillaume/jarry_cv_mva_competition.git
# Out:
# Cloning into 'jarry_cv_mva_competition'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 163 (delta 107), reused 107 (delta 51), pack-reused 0 (from 0)
# Receiving objects: 100% (163/163), 43.54 KiB | 21.77 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
import sys
import os
from google.colab import drive
sys.path.append("jarry_cv_mva_competition")
sys.path.append("drive/MyDrive/models")
from IPython.display import clear_output
import torch
import matplotlib as plt
from jarry_cv_mva_competition.main import main
from jarry_cv_mva_competition.evaluate import test
from jarry_cv_mva_competition.model_factory import ModelFactory

# %%
model_type = None
model_name = "mobileNet"
model_path = "drive/MyDrive/experiment/best_" + model_name + ".pth"

main(
         data_folder="drive/MyDrive/mva_competition",
         experiment_folder="drive/MyDrive/experiment",
         model_name=model_name,
         model_path=model_path,
         batch_size=48,
         num_workers=6,
         momentum=0.5,
         epochs=100,
         seed=42,
         lr_body=1e-5,
         saving_frequency=5,
         log_interval=50,
         optimizer="Adam",
     )
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /content/jarry_cv_mva_competition/model_factory.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(self.model_path)
# Succesfully loaded weights
# mobileNet used
# Using GPU
# Train Epoch: 1 [0/20000 (0%)]	Loss: 4.118952
# Train Epoch: 1 [2400/20000 (12%)]	Loss: 4.274922
# Train Epoch: 1 [4800/20000 (24%)]	Loss: 4.346594
# Train Epoch: 1 [7200/20000 (36%)]	Loss: 4.045321
# Train Epoch: 1 [9600/20000 (48%)]	Loss: 4.306340
# Train Epoch: 1 [12000/20000 (60%)]	Loss: 4.325979
# Train Epoch: 1 [14400/20000 (72%)]	Loss: 3.940711
# Train Epoch: 1 [16800/20000 (84%)]	Loss: 4.616488
# Train Epoch: 1 [19200/20000 (96%)]	Loss: 4.167833
# Epoch : 1, Training accuracy : 23.40999984741211 %
# Epoch : 1, Validation accuracy : 32.31999969482422 %
# Train Epoch: 2 [0/20000 (0%)]	Loss: 4.003856
# Train Epoch: 2 [2400/20000 (12%)]	Loss: 3.690073
# Train Epoch: 2 [4800/20000 (24%)]	Loss: 4.271918
# Train Epoch: 2 [7200/20000 (36%)]	Loss: 4.345076
# Train Epoch: 2 [9600/20000 (48%)]	Loss: 4.151078
# Train Epoch: 2 [12000/20000 (60%)]	Loss: 4.326283
# Train Epoch: 2 [14400/20000 (72%)]	Loss: 4.389656
# Train Epoch: 2 [16800/20000 (84%)]	Loss: 4.743506
# Train Epoch: 2 [19200/20000 (96%)]	Loss: 4.164706
# Epoch : 2, Training accuracy : 23.6299991607666 %
# Epoch : 2, Validation accuracy : 32.20000076293945 %
# Train Epoch: 3 [0/20000 (0%)]	Loss: 4.296258
# Train Epoch: 3 [2400/20000 (12%)]	Loss: 3.791601
# Train Epoch: 3 [4800/20000 (24%)]	Loss: 4.532027
# Train Epoch: 3 [7200/20000 (36%)]	Loss: 4.156142
# Train Epoch: 3 [9600/20000 (48%)]	Loss: 4.593764
# Train Epoch: 23 [16800/20000 (84%)]	Loss: 4.161613
# Train Epoch: 23 [19200/20000 (96%)]	Loss: 4.306923
# Epoch : 23, Training accuracy : 23.459999084472656 %
# Epoch : 23, Validation accuracy : 32.119998931884766 %
# Train Epoch: 24 [0/20000 (0%)]	Loss: 4.061788
# Train Epoch: 24 [2400/20000 (12%)]	Loss: 4.257966
# Train Epoch: 24 [4800/20000 (24%)]	Loss: 4.089565
# Train Epoch: 24 [7200/20000 (36%)]	Loss: 4.237872
# Train Epoch: 24 [9600/20000 (48%)]	Loss: 3.974750
# Train Epoch: 24 [12000/20000 (60%)]	Loss: 4.082102
# Train Epoch: 24 [14400/20000 (72%)]	Loss: 4.743937
# Train Epoch: 24 [16800/20000 (84%)]	Loss: 4.708320
# Train Epoch: 24 [19200/20000 (96%)]	Loss: 4.285024
# Epoch : 24, Training accuracy : 23.5049991607666 %
# Epoch : 24, Validation accuracy : 32.279998779296875 %
# Train Epoch: 25 [0/20000 (0%)]	Loss: 4.320004
# Train Epoch: 25 [2400/20000 (12%)]	Loss: 4.058285
# Train Epoch: 25 [4800/20000 (24%)]	Loss: 4.204613
# Train Epoch: 25 [7200/20000 (36%)]	Loss: 4.218370
# Train Epoch: 25 [9600/20000 (48%)]	Loss: 4.115932
# Train Epoch: 25 [12000/20000 (60%)]	Loss: 4.110663
# Train Epoch: 25 [14400/20000 (72%)]	Loss: 3.787874
# Train Epoch: 25 [16800/20000 (84%)]	Loss: 4.164859
# Train Epoch: 25 [19200/20000 (96%)]	Loss: 4.078572
# Epoch : 25, Training accuracy : 23.834999084472656 %
# Epoch : 25, Validation accuracy : 32.31999969482422 %
# Train Epoch: 26 [0/20000 (0%)]	Loss: 4.098664
# Train Epoch: 26 [2400/20000 (12%)]	Loss: 4.214272
# Train Epoch: 26 [4800/20000 (24%)]	Loss: 4.212087
# Train Epoch: 26 [7200/20000 (36%)]	Loss: 4.150670
# Train Epoch: 26 [9600/20000 (48%)]	Loss: 3.940859
# Train Epoch: 26 [12000/20000 (60%)]	Loss: 4.322996
# Train Epoch: 26 [14400/20000 (72%)]	Loss: 3.905896
# Train Epoch: 26 [16800/20000 (84%)]	Loss: 4.267239
# Train Epoch: 26 [19200/20000 (96%)]	Loss: 4.224942
# Epoch : 26, Training accuracy : 23.639999389648438 %
# Epoch : 26, Validation accuracy : 32.15999984741211 %
# Train Epoch: 27 [0/20000 (0%)]	Loss: 4.060639
# Train Epoch: 27 [2400/20000 (12%)]	Loss: 4.514625
# Train Epoch: 27 [4800/20000 (24%)]	Loss: 3.952595
# Train Epoch: 27 [7200/20000 (36%)]	Loss: 4.301929
# Train Epoch: 27 [9600/20000 (48%)]	Loss: 4.325424
# Train Epoch: 27 [12000/20000 (60%)]	Loss: 4.374793
# Train Epoch: 27 [14400/20000 (72%)]	Loss: 4.089823
# Train Epoch: 27 [16800/20000 (84%)]	Loss: 4.225589
# Train Epoch: 27 [19200/20000 (96%)]	Loss: 3.927421
# Epoch : 27, Training accuracy : 23.719999313354492 %
# Epoch : 27, Validation accuracy : 31.959999084472656 %
# Train Epoch: 28 [0/20000 (0%)]	Loss: 4.416189
# Train Epoch: 28 [2400/20000 (12%)]	Loss: 3.962856
# Train Epoch: 28 [4800/20000 (24%)]	Loss: 3.944501
# Train Epoch: 28 [7200/20000 (36%)]	Loss: 4.359933
# Train Epoch: 28 [9600/20000 (48%)]	Loss: 3.851280
# Train Epoch: 28 [12000/20000 (60%)]	Loss: 4.408313
# Train Epoch: 28 [14400/20000 (72%)]	Loss: 4.015249

# %%
model_type = "vit_base_patch16_224"
tuning_layers = 5
model_name = "vit_" + model_type + f"_fine_tuned_{tuning_layers}"
model_path = "drive/MyDrive/experiment/" + model_name + "80.pth"

test(
    model_name=model_name,
    model_path=model_path,
    model_type=model_type,
    outfile=f"drive/MyDrive/test_results/{model_name}.csv",
    data="drive/MyDrive/mva_competition",
    batch_size=128,
    num_workers=4,
    hidden_size=None,
    dropout=0
)
# Out:
# Using the Vision Transformer architecture.
# Succesfully loaded weights
# successfully parrallelized
# Using GPU
# Validation loss : 1.5316012442111968, Validation accuracy : 86.4800033569336 %
# 100%|██████████| 5455/5455 [04:31<00:00, 20.07it/s]
# Succesfully wrote drive/MyDrive/test_results/vit_vit_base_patch16_224_fine_tuned_5.csv, you can upload this file to the kaggle competition website

# %%
model_type = "vit_base_patch16_224"
tuning_layers = 3
model_name = "vit_" + model_type + f"_fine_tuned_{tuning_layers}"
model_path = "drive/MyDrive/experiment/" + model_name + "_5.pth"

main(
         data_folder="drive/MyDrive/mva_competition",
         experiment_folder="drive/MyDrive/experiment",
         model_name=model_name,
         model_type=model_type,
         model_path=model_path,
         batch_size=128,
         num_workers=2,
         momentum=0.5,
         epochs=100,
         seed=42,
         hidden_layers=128,
         lr_head=1e-4,
         lr_body=1e-5,
         saving_frequency=5,
         log_interval=20,
         tuning_layers=tuning_layers,
         fine_tune=True,
         optimizer="AdamW",
         dropout=0.05
     )
# Out:
# Using the Vision Transformer architecture.
# Succesfully loaded weights
# successfully parrallelized
# Using GPU

# %%
model_type = "vit_base_patch16_224"
tuning_layers = 6
lr_head = 2e-5
lr_body = 2e-5
model_name = "vit_" + model_type + f"_fine_tuned_{tuning_layers}_{lr_body}_{lr_head}"
model_path = "drive/MyDrive/experiment/best_" + model_name + ".pth"

main(
         data_folder="drive/MyDrive/mva_competition",
         experiment_folder="drive/MyDrive/experiment",
         model_name=model_name,
         model_type=model_type,
         model_path=None,
         batch_size=128,
         num_workers=2,
         momentum=0.5,
         epochs=100,
         seed=42,
         hidden_layers=None,
         lr_head=1e-3,
         lr_body=1e-4,
         saving_frequency=5,
         log_interval=50,
         tuning_layers=tuning_layers,
         fine_tune=True,
         optimizer="AdamW",
     )
